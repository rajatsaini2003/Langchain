# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.2', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000002AB1AA1EAE0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002AB1B08D640>, root_client=<openai.OpenAI object at 0x000002AB1A97FDD0>, root_async_client=<openai.AsyncOpenAI object at 0x000002AB1A9DA3C0>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
## invoke model
response = model.invoke("Hello how are you?")
response
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1904, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1903 else:
# -> 1904     raw_response = self.client.with_raw_response.create(**payload)
#    1905     response = raw_response.parse()
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1308, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1307 validate_response_format(response_format)
# -> 1308 return self._post(
#    1309     "/chat/completions",
#    1310     body=maybe_transform(
#    1311         {
#    1312             "messages": messages,
#    1313             "model": model,
#    1314             "audio": audio,
#    1315             "frequency_penalty": frequency_penalty,
#    1316             "function_call": function_call,
#    1317             "functions": functions,
#    1318             "logit_bias": logit_bias,
#    1319             "logprobs": logprobs,
#    1320             "max_completion_tokens": max_completion_tokens,
#    1321             "max_tokens": max_tokens,
#    1322             "metadata": metadata,
#    1323             "modalities": modalities,
#    1324             "moderation": moderation,
#    1325             "n": n,
#    1326             "parallel_tool_calls": parallel_tool_calls,
#    1327             "prediction": prediction,
#    1328             "presence_penalty": presence_penalty,
#    1329             "prompt_cache_key": prompt_cache_key,
#    1330             "prompt_cache_options": prompt_cache_options,
#    1331             "prompt_cache_retention": prompt_cache_retention,
#    1332             "reasoning_effort": reasoning_effort,
#    1333             "response_format": response_format,
#    1334             "safety_identifier": safety_identifier,
#    1335             "seed": seed,
#    1336             "service_tier": service_tier,
#    1337             "stop": stop,
#    1338             "store": store,
#    1339             "stream": stream,
#    1340             "stream_options": stream_options,
#    1341             "temperature": temperature,
#    1342             "tool_choice": tool_choice,
#    1343             "tools": tools,
#    1344             "top_logprobs": top_logprobs,
#    1345             "top_p": top_p,
#    1346             "user": user,
#    1347             "verbosity": verbosity,
#    1348             "web_search_options": web_search_options,
#    1349         },
#    1350         completion_create_params.CompletionCreateParamsStreaming
#    1351         if stream
#    1352         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1353     ),
#    1354     options=make_request_options(
#    1355         extra_headers=extra_headers,
#    1356         extra_query=extra_query,
#    1357         extra_body=extra_body,
#    1358         timeout=timeout,
#    1359         security={"bearer_auth": True},
#    1360     ),
#    1361     cast_to=ChatCompletion,
#    1362     stream=stream or False,
#    1363     stream_cls=Stream[ChatCompletionChunk],
#    1364 )
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1140     log.debug("Re-raising status error")
# -> 1141     raise self._make_status_error_from_response(err.response) from None
#    1143 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}
#
# The above exception was the direct cause of the following exception:
#
# OpenAIRateLimitError                      Traceback (most recent call last)
# Cell In[4], line 2
#       1 ## invoke model
# ----> 2 response = model.invoke("Hello how are you?")
#       3 response
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)   1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1909, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1907     _handle_openai_bad_request(e)
#    1908 except openai.APIError as e:
# -> 1909     _handle_openai_api_error(e)
#    1910 except Exception as e:
#    1911     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:668, in _handle_openai_api_error(e)
#     664     raise OpenAIModelNotFoundError(
#     665         message=e.message, response=e.response, body=e.body
#     666     ) from e
#     667 if isinstance(e, openai.RateLimitError):
# --> 668     raise OpenAIRateLimitError(
#     669         message=e.message, response=e.response, body=e.body
#     670     ) from e
#     671 if isinstance(e, openai.InternalServerError):
#     672     raise OpenAIAPIError(message=e.message, response=e.response, body=e.body) from e
#
# OpenAIRateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %% [markdown]
# ## Google Gemini Model Integration

# %%
from langchain.chat_models import init_chat_model
model_google = init_chat_model("google_genai:gemini-3.5-flash-lite")
res = model_google.invoke("Hello who are you?")
res.content
# Out:
# [{'type': 'text',
#   'text': 'Hello! I am an AI, a large language model trained by Google. How can I help you today?',
#   'extras': {'signature': 'El4KXAERTTIPQJNdscqbZhLUYTyVAtCkDW/JH9g39n1Dco2rN1t+ak4+oshRJwSwFSYnEfaKsaLu+Pjiy5AJsTpCVs6f350lmfglKe5Ig5LzUphSRMZKMMg821W1fmt2'}}]

# %%
# chat openAI
from langchain_openai import ChatOpenAI
model_openai = ChatOpenAI(model="gpt-4.1")
response = model_openai.invoke("Hello who are you?")
response
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1904, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1903 else:
# -> 1904     raw_response = self.client.with_raw_response.create(**payload)
#    1905     response = raw_response.parse()
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1308, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1307 validate_response_format(response_format)
# -> 1308 return self._post(
#    1309     "/chat/completions",
#    1310     body=maybe_transform(
#    1311         {
#    1312             "messages": messages,
#    1313             "model": model,
#    1314             "audio": audio,
#    1315             "frequency_penalty": frequency_penalty,
#    1316             "function_call": function_call,
#    1317             "functions": functions,
#    1318             "logit_bias": logit_bias,
#    1319             "logprobs": logprobs,
#    1320             "max_completion_tokens": max_completion_tokens,
#    1321             "max_tokens": max_tokens,
#    1322             "metadata": metadata,
#    1323             "modalities": modalities,
#    1324             "moderation": moderation,
#    1325             "n": n,
#    1326             "parallel_tool_calls": parallel_tool_calls,
#    1327             "prediction": prediction,
#    1328             "presence_penalty": presence_penalty,
#    1329             "prompt_cache_key": prompt_cache_key,
#    1330             "prompt_cache_options": prompt_cache_options,
#    1331             "prompt_cache_retention": prompt_cache_retention,
#    1332             "reasoning_effort": reasoning_effort,
#    1333             "response_format": response_format,
#    1334             "safety_identifier": safety_identifier,
#    1335             "seed": seed,
#    1336             "service_tier": service_tier,
#    1337             "stop": stop,
#    1338             "store": store,
#    1339             "stream": stream,
#    1340             "stream_options": stream_options,
#    1341             "temperature": temperature,
#    1342             "tool_choice": tool_choice,
#    1343             "tools": tools,
#    1344             "top_logprobs": top_logprobs,
#    1345             "top_p": top_p,
#    1346             "user": user,
#    1347             "verbosity": verbosity,
#    1348             "web_search_options": web_search_options,
#    1349         },
#    1350         completion_create_params.CompletionCreateParamsStreaming
#    1351         if stream
#    1352         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1353     ),
#    1354     options=make_request_options(
#    1355         extra_headers=extra_headers,
#    1356         extra_query=extra_query,
#    1357         extra_body=extra_body,
#    1358         timeout=timeout,
#    1359         security={"bearer_auth": True},
#    1360     ),
#    1361     cast_to=ChatCompletion,
#    1362     stream=stream or False,
#    1363     stream_cls=Stream[ChatCompletionChunk],
#    1364 )
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\_base_client.py:1368, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365 opts = FinalRequestOptions.construct(
#    1366     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1367 )
# -> 1368 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\openai\_base_client.py:1141, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1140     log.debug("Re-raising status error")
# -> 1141     raise self._make_status_error_from_response(err.response) from None
#    1143 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}
#
# The above exception was the direct cause of the following exception:
#
# OpenAIRateLimitError                      Traceback (most recent call last)
# Cell In[10], line 4
#       1 # chat openAI
#       2 from langchain_openai import ChatOpenAI
#       3 model_openai = ChatOpenAI(model="gpt-4.1")
# ----> 4 response = model_openai.invoke("Hello who are you?")
#       5 response
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)   1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1909, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1907     _handle_openai_bad_request(e)
#    1908 except openai.APIError as e:
# -> 1909     _handle_openai_api_error(e)
#    1910 except Exception as e:
#    1911     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File f:\Switch\AI\LangchainProject\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:668, in _handle_openai_api_error(e)
#     664     raise OpenAIModelNotFoundError(
#     665         message=e.message, response=e.response, body=e.body
#     666     ) from e
#     667 if isinstance(e, openai.RateLimitError):
# --> 668     raise OpenAIRateLimitError(
#     669         message=e.message, response=e.response, body=e.body
#     670     ) from e
#     671 if isinstance(e, openai.InternalServerError):
#     672     raise OpenAIAPIError(message=e.message, response=e.response, body=e.body) from e
#
# OpenAIRateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model_google = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
res = model_google.invoke("Hello who are you?")
res
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Hello! I am an AI, a large language model trained by Google. How can I help you today?', 'extras': {'signature': 'El4KXAERTTIPU32v6uUwnw6ok0UJtVse5Zjb4rQ8j9gLyepHN/dGl7aViTyh4IzdsvaGQ6rNvcE+K8xADoMtIp789lnDxn/mamMS0dSoX+MCn1PFP6guMl//cnNJRSIN'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a09150-08a9-7f40-9db3-5722c091d246-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 22, 'total_tokens': 28, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# ## GROQ Model Integration

# %%
from langchain.chat_models import init_chat_model

model_groq = init_chat_model("groq:openai/gpt-oss-20b")
res = model_groq.invoke("Hello who are you?")
res
# Out:
# AIMessage(content='Hello! I’m ChatGPT, a large language model created by OpenAI. I can help answer questions, brainstorm ideas, explain concepts, draft emails, write code snippets, and much more. What can I help you with today?', additional_kwargs={'reasoning_content': 'We need to respond in a friendly manner, but also note we are ChatGPT. The user: "Hello who are you?" So answer: I\'m ChatGPT, AI. We can mention capabilities, maybe ask what they need.'}, response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 76, 'total_tokens': 179, 'completion_time': 0.10862109, 'completion_tokens_details': {'reasoning_tokens': 47}, 'prompt_time': 0.004331491, 'prompt_tokens_details': None, 'queue_time': 0.045367719, 'total_time': 0.112952581}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_c5a89987dc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0916d-4c6b-7043-a16f-82a1c2422158-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 76, 'output_tokens': 103, 'total_tokens': 179, 'output_token_details': {'reasoning': 47}})

# %% [markdown]
# ## Streaming And Batch
# ## Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
## no streaming
model_groq.invoke("Write a 100 words essay about socialism vs capitalism.")
# Out:
# AIMessage(content='Socialism and capitalism represent two distinct economic philosophies shaping societies worldwide. Capitalism prioritizes private ownership, free markets, and individual profit, driving innovation and competition but often creating inequality and market volatility. Socialism emphasizes collective ownership, wealth redistribution, and social welfare, aiming for equality and stability, yet it can stifle personal incentives and limit efficiency. Both systems have strengths and weaknesses, and many modern nations adopt mixed models to balance growth with social protection. Ultimately, the debate centers on how best to combine economic freedom with collective responsibility to achieve prosperity for all. Public debate continues as societies evolve everywhere daily.', additional_kwargs={'reasoning_content': 'The user wants a 100-word essay about socialism vs capitalism. The user likely wants exactly 100 words. We need to produce an essay of exactly 100 words. Let\'s count words. We need to ensure we count correctly. Let\'s draft.\n\nWe need to include both socialism and capitalism. The essay should be 100 words exactly. Let\'s craft:\n\n"Socialism and capitalism represent two distinct economic philosophies shaping societies worldwide. Capitalism prioritizes private ownership, free markets, and individual profit, driving innovation and competition but often creating inequality and market volatility. Socialism emphasizes collective ownership, wealth redistribution, and social welfare, aiming for equality and stability, yet it can stifle personal incentives and limit efficiency. Both systems have strengths and weaknesses, and many modern nations adopt mixed models to balance growth with social protection. Ultimately, the debate centers on how best to combine economic freedom with collective responsibility to achieve prosperity for all."\n\nNow count words. Let\'s count manually:\n\nSocialism(1) and(2) capitalism(3) represent(4) two(5) distinct(6) economic(7) philosophies(8) shaping(9) societies(10) worldwide.(11) Capitalism(12) prioritizes(13) private(14) ownership,(15) free(16) markets,(17) and(18) individual(19) profit,(20) driving(21) innovation(22) and(23) competition(24) but(25) often(26) creating(27) inequality(28) and(29) market(30) volatility.(31) Socialism(32) emphasizes(33) collective(34) ownership,(35) wealth(36) redistribution,(37) and(38) social(39) welfare,(40) aiming(41) for(42) equality(43) and(44) stability,(45) yet(46) it(47) can(48) stifle(49) personal(50) incentives(51) and(52) limit(53) efficiency.(54) Both(55) systems(56) have(57) strengths(58) and(59) weaknesses,(60) and(61) many(62) modern(63) nations(64) adopt(65) mixed(66) models(67) to(68) balance(69) growth(70) with(71) social(72) protection.(73) Ultimately,(74) the(75) debate(76) centers(77) on(78) how(79) best(80) to(81) combine(82) economic(83) freedom(84) with(85) collective(86) responsibility(87) to(88) achieve(89) prosperity(90) for(91) all.(92)\n\nWe have 92 words. Need 8 more words. Add a sentence of 8 words. For example: "Public debate continues as societies evolve." Count: Public(1) debate(2) continues(3) as(4) societies(5) evolve(6). That\'s 6 words. Need 2 more words. Add "daily." Actually "daily" is one. So 7. Maybe "everywhere." So "Public debate continues as societies evolve everywhere." Count: Public(1) debate(2) continues(3) as(4) societies(5) evolve(6) everywhere(7). Need 1 more word. Add "daily." So: "Public debate continues as societies evolve everywhere daily." Count: Public(1) debate(2) continues(3) as(4) societies(5) evolve(6) everywhere(7) daily(8). Good.\n\nNow total words: 92 + 8 = 100. Let\'s add that sentence at the end of the essay.\n\nFull essay:\n\n"Socialism and capitalism represent two distinct economic philosophies shaping societies worldwide. Capitalism prioritizes private ownership, free markets, and individual profit, driving innovation and competition but often creating inequality and market volatility ...

# %%
## streaming 
for chunk in model_groq.stream("Write a 100 words essay about socialism vs capitalism."):
    print(chunk.text, end="|", flush =True)
# Out:
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||Social|ism| and| capitalism| represent| two| distinct| economic| philosophies|,| each| shaping| society| in| profound| ways|.| Capital|ism| emphasizes| private| ownership|,| market| competition|,| and| individual| profit|,| fostering| innovation| but| often| producing| inequality|.| Social|ism| priorit|izes| collective| ownership|,| equitable| resource| distribution|,| and| social| welfare|,| aiming| for| fairness| but| sometimes| limiting| entrepreneurial| incentives|.| Both| systems| influence| political| structures|,| cultural| values|,| and| global| power| dynamics|.| The| debate| centers| on| balancing| efficiency| with| equity|,| freedom| with| security|.| In| practice|,| most| nations| blend| elements| of| both|,| creating| mixed| economies| that| strive| to| harness| the| strengths| of| each| while| mitigating| their| weaknesses|.| This| ongoing| dialogue| shapes| policy| decisions| worldwide| today|.|||

# %% [markdown]
# ## Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
res = model_groq.batch([
    "what is the capital of France?",
    "who attacked Pearl Harbor?",
    "what is quantum computing?",
],
config={
    "max_concurrency": 3
    })
for response in res:
    print(response)
# Out:
# content='The capital of France is **Paris**.' additional_kwargs={'reasoning_content': 'We need to respond: The capital of France is Paris. Provide a concise answer.'} response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 78, 'total_tokens': 114, 'completion_time': 0.042676674, 'completion_tokens_details': {'reasoning_tokens': 18}, 'prompt_time': 0.00515137, 'prompt_tokens_details': None, 'queue_time': 0.347454497, 'total_time': 0.047828044}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_976a85d17a', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a09182-5a10-71e0-868c-df8ddbf53db9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 78, 'output_tokens': 36, 'total_tokens': 114, 'output_token_details': {'reasoning': 18}}
# content='Pearl Harbor was attacked by the **Imperial Japanese Navy** on December\u202f7,\u202f1941. The surprise strike was launched from Japanese aircraft carriers and carried out by Japanese pilots and naval forces under the command of Admiral Isoroku\u202fYamamoto.' additional_kwargs={'reasoning_content': 'User asks: "who attacked Pearl Harbor?" This is a straightforward historical question. The answer: Japanese forces attacked Pearl Harbor on December 7, 1941. The attacker was the Imperial Japanese Navy. Provide context: Japanese military, commanded by Admiral Isoroku Yamamoto, etc. Also mention that it was a surprise attack by Japanese aircraft carriers. Provide details. The user may want a concise answer. Should be factual. Also consider user might want more context. Provide a short answer. No policy issues. Provide answer.'} response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 76, 'total_tokens': 245, 'completion_time': 0.225966195, 'completion_tokens_details': {'reasoning_tokens': 107}, 'prompt_time': 0.00372145, 'prompt_tokens_details': None, 'queue_time': 0.315317027, 'total_time': 0.229687645}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_66891002f6', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a09182-5a14-7453-8dd1-1c5c3aa1d79f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 76, 'output_tokens': 169, 'total_tokens': 245, 'output_token_details': {'reasoning': 107}}
# content='## Quantum Computing in a Nutshell\n\n| Classical computer | Quantum computer |\n|---------------------|------------------|\n| **Bits** – 0 or 1 | **Qubits** – 0, 1, *or both at once* (superposition) |\n| Deterministic logic gates | Probabilistic, interference‑based gates |\n| Processes one state at a time | Exploits parallelism through superposition and entanglement |\n| Uses silicon, CMOS, etc. | Uses superconductors, trapped ions, photonics, topological defects, etc. |\n\n---\n\n### 1. What Is It?\n\nQuantum computing is a new paradigm that uses the principles of quantum mechanics to perform calculations. Instead of manipulating bits, a quantum computer manipulates *quantum bits* (qubits), which can exist in a superposition of states and can be entangled with one another. This allows a quantum computer to explore many possible solutions simultaneously, potentially solving certain problems far faster than any classical computer.\n\n---\n\n### 2. Core Quantum Principles\n\n| Principle | Classical Analogy | Quantum Effect |\n|-----------|-------------------|----------------|\n| **Superposition** | A coin is either heads or tails. | A qubit can be *both* 0 and 1 at the same time. |\n| **Entanglement** | Two coins can be correlated (e.g., both heads). | Two qubits can share a state such that measuring one instantly determines the state of the other, regardless of distance. |\n| **Interference** | Adding two waves can cancel or reinforce each other. | Quantum gates manipulate the probability amplitudes of qubit states so that correct answers interfere constructively and wrong ones destructively. |\n\n---\n\n### 3. How Does a Quantum Computer Work?\n\n1. **Initialize** the qubits to a known state (usually |0⟩).\n2. **Apply quantum gates** (analogous to classical logic gates) that create superposition, entanglement, and interference.\n3. **Measure** the qubits. Measurement collapses the quantum state to a classical bitstring, giving you the result.\n\nBecause of superposition, a quantum computer with *n* qubits can represent \\(2^n\\) different states simultaneously. However, you only get one measurement outcome, so the real power comes from *quantum algorithms* that amplify the probability of the correct answer.\n\n---\n\n### 4. Famous Quantum Algorithms\n\n| Problem | Classical Complexity | Quantum Complexity | Key Idea |\n|---------|----------------------|--------------------|----------|\n| **Factoring integers** (e.g., RSA) | Exponential (≈\u202f2^n) | Polynomial (≈\u202fO((log\u202fN)^3)) | Shor’s algorithm uses quantum Fourier transform to find periodicity. |\n| **Unstructured search** | O(N) | O(√N) | Grover’s algorithm uses amplitude amplification. |\n| **Simulating quantum systems** | Exponential | Polynomial (for many cases) | Directly maps the problem onto qubits, avoiding the exponential blow‑up. |\n\n---\n\n### 5. Current Quantum Hardware\n\n| Platform | Typical Qubit Count (as of 2026) | Key Challenge |\n|----------|----------------------------------|---------------|\n| **Superconducting qubits** (IBM, Google, Rigetti) | 500–1,000 | Coherence times, error rates |\n| **Trapped‑ion qubits** (IonQ, Honeywell) | 100–200 | Scaling to many qubits |\n| **Photonic qubits** (PsiQuantum) | 50–200 | Losses, deterministic gates |\n| **Topological qubits** (Microsoft) | 20–30 | Still experimental |\n| **Hybrid/analog** (D-Wave) | 5,000+ | Not universal, specialized problems |\n\n**Key metrics** for progress:\n- **Coherence time** (how long a qubit stays in a superposition)\n- **Gate fidelity** (accuracy of quantum operations)\n- **Error‑correction overhead** (how many physical qubits per logical qubit)\n\n---\n\n### 6. Applications (Beyond “faster computing”)\n\n| Domain | What quantum can help with | Why it matters |\n|--------|----------------------------|----------------|\n| **Cryptography** | Breaking RSA/ElGamal with Shor’s algorithm | Secure communications may need quantum‑safe cryptography |\n| **Materials science* ...
